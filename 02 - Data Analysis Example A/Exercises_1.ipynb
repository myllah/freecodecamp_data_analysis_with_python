# %% [markdown]
# <a href="https://colab.research.google.com/github/myllah/freecodecamp_data_analysis_with_python/blob/main/02%20-%20Data%20Analysis%20Example%20A/Exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/myllah/freecodecamp_data_analysis_with_python/7f371b252e4e5a933335bbabcc7263d05fad2f52/02%20-%20Data%20Analysis%20Example%20A/data/sales_data.csv'
#url = 'data/sales_data.csv'

sales = pd.read_csv(url, parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here

sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here

sales['Customer_Age'].plot(kind='kde', grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# your code goes here

sales['Customer_Age'].plot(kind='box', vert=False, grid=True)
# Out:
# <Axes: >

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', xlabel='Order Quantity', grid=True, title='Histogram of Order Quantity')
# Out:
# <Axes: title={'center': 'Histogram of Order Quantity'}, xlabel='Order Quantity', ylabel='Frequency'>

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='box', grid=True, title='Box Plot of Order Quantity', vert=False)
# Out:
# <Axes: title={'center': 'Box Plot of Order Quantity'}>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].value_counts()
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales_per_year = sales['Year'].value_counts()

sales_per_year.plot(kind='pie', title='Sales per Year', autopct=lambda p: '{:.0f}'.format(p * sum(sales_per_year) / 100), ylabel='')
# Out:
# <Axes: title={'center': 'Sales per Year'}>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar', title='Sales per Month')
# Out:
# <Axes: title={'center': 'Sales per Month'}, xlabel='Month'>

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales['Country'].value_counts().idxmax()
# Out:
# 'United States'

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind='bar', title='Sales per Country')
# Out:
# <Axes: title={'center': 'Sales per Country'}, xlabel='Country'>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales['Product'].value_counts().head(10).plot(kind='bar', title='10 Most Sold Products')
# Out:
# <Axes: title={'center': '10 Most Sold Products'}, xlabel='Product'>

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', title='Relationship beetween Unit Cost and Unit Price')
# Out:
# <Axes: title={'center': 'Relationship beetween Unit Cost and Unit Price'}, xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', title='Relationship beetween Order Quantity and Profit')
# Out:
# <Axes: title={'center': 'Relationship beetween Order Quantity and Profit'}, xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales.plot(kind='box',column='Profit', by='Country', title='Relationship between Profit per Country')
# Out:
# Profit    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales.plot(kind='box',column='Customer_Age', by='Country', title='Ralationship between Custumer Age per Country')
# Out:
# Customer_Age    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
sales[['Year', 'Month', 'Day']].head(5)
# Out:
#    Year     Month  Day
# 0  2013  November   26
# 1  2015  November   26
# 2  2014     March   23
# 3  2016     March   23
# 4  2014       May   15

# %%
import calendar

# Assuming sales['Month'] contains month names like 'January', 'February', etc.
sales['Month_Index'] = sales['Month'].apply(lambda x: list(calendar.month_name).index(x.capitalize()))

sales['Calculated_Date'] = pd.to_datetime(sales[['Year', 'Month_Index', 'Day']].rename(columns={'Month_Index': 'month'}))
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3548\223435626.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
sales['Calculated_Date'].value_counts().plot(kind='line', title='Sales through years', ylabel='Sales Quantity', xlabel='Year')
# Out:
# <Axes: title={'center': 'Sales through years'}, xlabel='Year', ylabel='Sales Quantity'>

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue'] += 50

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here

sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 25176

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
sales.loc[sales['Country'] == 'France', 'State'].value_counts()
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
sales.loc[sales['Country'] == 'France', 'State'].value_counts().plot(kind='bar', title='Orders per State in France')
# Out:
# <Axes: title={'center': 'Orders per State in France'}, xlabel='State'>

# %%
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales_per_category = sales['Product_Category'].value_counts()

sales_per_category.plot(kind='pie', title='Sales per Product Category', autopct=lambda p: '{:.0f}%'.format(p), ylabel='')
# Out:
# <Axes: title={'center': 'Sales per Product Category'}>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts().plot(kind='bar', title='Orders by Sub-category of Accessories Category')
# Out:
# <Axes: title={'center': 'Orders by Sub-category of Accessories Category'}, xlabel='Sub_Category'>

# %%
accessories.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts().plot(kind='pie', title='Orders per Bike subcategories',autopct=lambda p: '{:.0f}%'.format(p), ylabel='')
# Out:
# <Axes: title={'center': 'Orders per Bike subcategories'}>

# %%
bikes.plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_Gender'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 9

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 9

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here
sales.sort_values(['Revenue'], ascending=False).head(1)
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue  Month_Index Calculated_Date
# 112073   15096  42978    58174            7      2015-07-24

# %%
# your code goes here
sales.loc[sales['Revenue'] == sales['Revenue'].max()]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue  Month_Index Calculated_Date
# 112073   15096  42978    58174            7      2015-07-24

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue  Month_Index Calculated_Date
# 112073   15096  42978    58174            7      2015-07-24

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
sales.loc[sales['Revenue'] >= 10_000, 'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
sales.loc[sales['Revenue'] < 10_000, 'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
sales.loc[(sales['Month'] == 'May') & (sales['Year'] == 2016)].shape[0]
# Out:
# 5015

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
sales.loc[(sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))]
# Out:
#              Date  Day Month  Year  Customer_Age             Age_Group  \
# 5      2016-05-15   15   May  2016            47        Adults (35-64)
# 7      2016-05-22   22   May  2016            47        Adults (35-64)
# 21     2016-05-17   17   May  2016            29  Young Adults (25-34)
# 33     2016-05-23   23   May  2016            47        Adults (35-64)
# 69     2016-06-19   19  June  2016            35        Adults (35-64)
# ...           ...  ...   ...   ...           ...                   ...
# 112985 2016-05-05    5   May  2016            25  Young Adults (25-34)
# 113001 2016-07-27   27  July  2016            34  Young Adults (25-34)
# 113003 2016-05-23   23   May  2016            20           Youth (<25)
# 113005 2016-05-03    3   May  2016            21           Youth (<25)
# 113019 2016-07-30   30  July  2016            33  Young Adults (25-34)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.plot(kind='box', column='Profit', by='Month', figsize=(14,4))
# Out:
# Profit    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3548\2621150480.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[128.64  128.64  128.64  ...  68.608  68.608  68.608]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
